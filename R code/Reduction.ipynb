# %% [markdown]
# ### Requirements

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib qt

# ONLY WORKS ON MY LAPTOP, COULDN'T GET THE PATH TO WORK FOR THE REMOTE REPO
direc = r"C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025"

# %% [markdown]
# ### Cropping

# %%
# READ FIRST IMAGE
image = fits.open(direc + r'\2025-10-09\PIRATE_165659_OSL_ROE_Asteroids_2_00_Standard_Star_1_00_Filter_R_00_2025_10_09_19_46_12.fits')[0].data

# REMOVE BORDER
image = image[21:2027,21:2027]

# PLOT
fig,ax = plt.subplots(figsize=(8,8))
ax.imshow(image, cmap='gray', vmax=1500)
plt.show()

# %%
# EXTRACT ALL FILES
files_day1 = os.listdir(r'C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025\2025-10-09')
files_day1 = [direc + r'\2025-10-09\\' + file for file in files_day1]
files_day2 = os.listdir(r'C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025\2025-10-19')
files_day2 = [direc + r'\2025-10-19\\' + file for file in files_day2]
files_day3 = os.listdir(r'C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025\2025-10-22')
files_day3 = [direc + r'\2025-10-22\\' + file for file in files_day3]
all_files = files_day1 + files_day2 + files_day3

for f in all_files:
    print(f)

# CROP ALL
cropped = {}
for file in all_files:
    cropped[file] = fits.open(file)[0].data[21:2027,21:2027]
# Out:
# C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025\2025-10-09\\PIRATE_165659_OSL_ROE_Asteroids_2_00_Standard_Star_1_00_Filter_R_00_2025_10_09_19_46_12.fits
# C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025\2025-10-09\\PIRATE_165660_OSL_ROE_Asteroids_2_00_Standard_Star_1_00_Filter_R_00_2025_10_09_19_49_46.fits
# C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025\2025-10-09\\PIRATE_165661_OSL_ROE_Asteroids_2_00_Standard_Star_1_00_Filter_R_00_2025_10_09_19_56_14.fits
# C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025\2025-10-09\\PIRATE_165662_OSL_ROE_Asteroids_2_00_Standard_Star_1_00_Filter_R_00_2025_10_09_19_56_37.fits
# C:\Users\rober\OneDrive\Documents\_Docs\Year 4\TGP\TGP_Asteroids2_2025\2025-10-09\\PIRATE_165663_OSL_ROE_Asteroids_2_00_Standard_Star_1_00_Filter_R_00_2025_10_09_19_58_56.fits
# ...

# %% [markdown]
# ### Bias
